# %%
from IPython.display import display
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras.applications.efficientnet import EfficientNetB7

# %%
effnet_application=EfficientNetB7(include_top=False,input_shape=(600,600,3),drop_connect_rate=0.71)
for i in range(4):
    effnet_application._layers.pop(0)

new_model=keras.Sequential([
    keras.layers.Input(shape=(600,600,3)),
    effnet_application
])

new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# efficientnetb7 (Functional)  (None, 19, 19, 2560)      64097680
# ...
# Total params: 64,097,680
# Trainable params: 63,786,960
# Non-trainable params: 310,720
# _________________________________________________________________

# %%
effnet_application=EfficientNetB7(include_top=False,input_shape=(600,600,3),drop_connect_rate=0.71)

# %%
effnet_application.layers
# Out:
# Model: "efficientnetb7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 600, 600, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 600, 600, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 600, 600, 3)  7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 601, 601, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
temp_weights=[layer.get_weights() for layer in effnet_application.layers]

# %%
display(len(temp_weights))
# Out:
# 813

# %%
layer_name="stem_conv"
new_model=models.Model(inputs=keras.layers.Input(shape=(600,600,3)),outputs=effnet_application.output)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-fa1654e0addf> in <module>
#       1 layer_name="stem_conv"
# ----> 2 new_model=models.Model(inputs=keras.layers.Input(shape=(600,600,3)),outputs=effnet_application.output)
#
# ~\anaconda3\envs\py38\lib\site-packages\tensorflow\python\keras\engine\training.py in __new__(cls, *args, **kwargs)
#     240       # Functional model
#     241       from tensorflow.python.keras.engine import functional  # pylint: disable=g-import-not-at-top
# --> 242       return functional.Functional(*args, **kwargs)
#     243     else:
#     244       return super(Model, cls).__new__(cls, *args, **kwargs)
#
# ~\anaconda3\envs\py38\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# ...

# %%
new_model.load_weights("./models/efficientnet-b7_noisy-student_notop/weight")

# %%
new_model.save("./models/temp")
# Out:
# WARNING:tensorflow:From C:\Users\kamim\anaconda3\envs\py38\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-259e1e81639c> in <module>
# ----> 1 new_model.save("./models/temp")
#
# ~\anaconda3\envs\py38\lib\site-packages\tensorflow\python\keras\engine\training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options)
#    1976     ```
#    1977     """
# -> 1978     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
#    1979                     signatures, options)
#    1980
#
# ...
